# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [22, 23, 21, 24, 25]
y = [2010, 2011, 2012, 2013, 2014]
plt.xlabel("Year")
plt.ylabel('Temperature (°C)')
plt.title ('Average Temperature Over Years')
plt.plot(x,y)

# %%
x = [150, 160, 165, 170, 175, 180]
y = [50, 55, 60, 65, 70, 75]
plt.xlabel("Height (cm)")
plt.ylabel('Weight (kg)')
plt.title ('Height vs Weight')
plt.scatter(x,y)

# %%
x = ['Math', 'Science', 'English', 'History']
y = [30, 25, 35, 20]
plt.xlabel("subjects")
plt.ylabel('students')
plt.title ('Number of Students per Subject')
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
activities = ['Sleep', 'Study', 'Exercise', 'Entertainment']
proportions = [8, 6, 2, 8]

plt.figure(figsize=(8, 6))
plt.pie(proportions, labels=activities, autopct='%1.1f%%')
plt.title('Daily Activity Distribution')

plt.show()
